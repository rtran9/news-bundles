# %%
import os
import re
import time

import lda
import nltk
import numpy as np
from datetime import datetime, timedelta
from nltk.tokenize import word_tokenize
from pymongo import MongoClient
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.decomposition import NMF, LatentDirichletAllocation
from scipy.sparse import dok_matrix
import matplotlib.pyplot as plt

# %%
MONGO_URL = 'mongodb://um.media.mit.edu:27017/super-glue'
db = MongoClient(MONGO_URL).get_default_database()

# %%
nlp_data = db['nlp_data'].find_one()
stopwords = nlp_data["stopwords"]
vocab = nlp_data["vocab_non_stemmed"]
vocab_dict = nlp_data["vocab_non_stemmed_dict"]

# %%
DAY = 86400000
HOUR = 3600000

def millis():
    return int(round(time.time() * 1000))
def millis_since(num_days='2'):
    days = int(os.environ.get('TIME_FRAME_DAYS', num_days))
    return millis() - days*DAY
def millis_since_hours(hours):
    return millis()-HOUR*hours

def get_vectors(media):
    segs = media["story_segments"]
    media_url = "media_url_no_comm"
    if not media["module_reports"]["commercial_skip_module"]["removed_commercials"]:
        media_url = "media_url"
    segs_vectors = []
    file_name = lambda x:''.join(x.split('.')[4:])
    for i in range (len(segs)):
        start = segs[i]["start"]
        end = segs[i]["end"]
        thumb = "/static/images/blank.jpg"
        if "thumbnail_image" in segs[i]:
            thumb = segs[i]["thumbnail_image"]
        url = "%s#t=%.2f,%.2f"%(media[media_url],start/1000.0,end/1000.0)
        air_date = media["date_added"]
        length = float(end)-float(start)
        if "word_count" in segs[i]:
            vector = segs[i]["word_count"]
            if len(vector.keys())>3 and length>4000:
                segs_vectors.append({
                    "start":start,
                    "end":end,
                    "url":url,
                    "channel":media["channel"],
                    "length":length,
                    "date":air_date,
                    "thumbnail":thumb,
                    "media_id": str(media["_id"]),
                    "segment_index": i,
                    "vector":vector})
    return segs_vectors

def get_all_segments(since_hour):
    all_media_has_segments = db['media'].find(
        {"date_added": {"$gt": millis_since_hours(since_hour+24), "$lt": millis_since_hours(since_hour)},
         "story_segments":{"$exists": True},"is_news":{"$eq": True}})
    num_of_videos = all_media_has_segments.count()
    print "%d videos"%num_of_videos
    # total_segments = 0
    all_segments = []
    for media in all_media_has_segments:
        segs = get_vectors(media)
        all_segments.extend(segs)
    print "%d total segments"%len(all_segments)
    return all_segments

# %%
def get_topic_words(topic_word, n_top_words):
    topic_summaries = []
    for i, topic_dist in enumerate(topic_word):
        topic_words = np.array(vocab)[np.argsort(topic_dist)][:-(n_top_words+1):-1]
        topic_summaries.append('-'.join(topic_words))
    return topic_summaries

def run_lda(all_segments):
    vectors = dok_matrix((len(all_segments), len(vocab)), dtype=np.int32)
    for i, seg in enumerate(all_segments):
        vec = seg["vector"]
        for ind in vec.keys():
            vectors[i, int(ind)] = int(vec[ind])
        seg.pop("vector")

    n_topics = len(all_segments)/9
    n_iter = 1000 #1000
    lda_model = lda.LDA(n_topics=n_topics, n_iter=n_iter)
    X_topics = lda_model.fit_transform(vectors)
    
    n_words_long = 40
    long_topic_summaries = get_topic_words(lda_model.topic_word_, n_words_long)

    clusters = []
    for i in range(n_topics):
        clusters.append([])
    doc_topic = lda_model.doc_topic_
    for i, seg in enumerate(all_segments):
        clusters[doc_topic[i].argmax()].append(seg)


    print
    long_results = []
    words_sizes = vectors.sum(axis=0)
    for i, topic in enumerate(long_topic_summaries):
        channels = list(set([seg["channel"] for seg in clusters[i] ]))
        segs_by_channel = [{"channel":channel,"videos":sorted([segm for segm in clusters[i] if segm["channel"]==channel],key=lambda x:x["date"])} for channel in channels]
        sorted_segs_by_channel = sorted(segs_by_channel, key=lambda x:len(x["videos"]), reverse=True)
        words = [{"text":word, "size":words_sizes[0, vocab.index(word)]} for word in topic.split('-')]
        long_topic = topic
        long_res = {
            'id':i,
            'summary':long_topic,
            'value':len(clusters[i]),
            'segments':sorted_segs_by_channel,
            'words':[{"text":word, "size":words_sizes[0, vocab.index(word)]} for word in long_topic.split('-')],
            'ratio':(len(clusters[i])*1.0)/(len(all_segments)*1.0)
            }

        long_results.append(long_res)
    return {'all_clusters': long_results}

# %%
clusters_collection = MongoClient(MONGO_URL)['perspectives']['clusters_full']
def add_data (since_hour):
    clus = run_lda(get_all_segments(since_hour))
    timestamp = int(time.mktime((datetime.now() - timedelta(hours=since_hour)).timetuple()))
    clus["timestamp"] = timestamp
    result = clusters_collection.insert_one(clus)
    print "added %d"%since_hour

# %%
hours_one_moth_ago = 10
since_hour = hours_one_moth_ago
while since_hour>3:
    add_data(since_hour)
    since_hour-=3
# Out:
# 114 videos
# 480 total segments
# INFO:lda:n_documents: 480
# INFO:lda:vocab_size: 33701
# INFO:lda:n_words: 95083
# INFO:lda:n_topics: 53
# INFO:lda:n_iter: 1000
# WARNING:lda:all zero column in document-term matrix found
# INFO:lda:<0> log likelihood: -1320262
# INFO:lda:<10> log likelihood: -894486
# INFO:lda:<20> log likelihood: -860731
# INFO:lda:<30> log likelihood: -846019
# INFO:lda:<40> log likelihood: -837625
# INFO:lda:<50> log likelihood: -832141
# INFO:lda:<60> log likelihood: -827858
# INFO:lda:<70> log likelihood: -823814
# INFO:lda:<80> log likelihood: -819879
# INFO:lda:<90> log likelihood: -817217
# INFO:lda:<100> log likelihood: -814887
# INFO:lda:<110> log likelihood: -812190
# INFO:lda:<120> log likelihood: -809619
# INFO:lda:<130> log likelihood: -808003
# INFO:lda:<140> log likelihood: -806727
# INFO:lda:<150> log likelihood: -804664
# INFO:lda:<160> log likelihood: -803239
# INFO:lda:<170> log likelihood: -802713
# INFO:lda:<180> log likelihood: -801719
# INFO:lda:<190> log likelihood: -800825
# INFO:lda:<200> log likelihood: -798737
# INFO:lda:<210> log likelihood: -798626
# INFO:lda:<220> log likelihood: -797207
# INFO:lda:<230> log likelihood: -795609
# INFO:lda:<240> log likelihood: -795611
# INFO:lda:<250> log likelihood: -795117
# INFO:lda:<260> log likelihood: -795168
# INFO:lda:<270> log likelihood: -793966
# INFO:lda:<280> log likelihood: -793131
# INFO:lda:<290> log likelihood: -792956
# INFO:lda:<300> log likelihood: -792571
# INFO:lda:<310> log likelihood: -791971
# INFO:lda:<320> log likelihood: -791230
# INFO:lda:<330> log likelihood: -791225
# INFO:lda:<340> log likelihood: -790884
# INFO:lda:<350> log likelihood: -790180
# INFO:lda:<360> log likelihood: -789278
# INFO:lda:<370> log likelihood: -788717
# INFO:lda:<380> log likelihood: -788304
# INFO:lda:<390> log likelihood: -787780
# INFO:lda:<400> log likelihood: -787385
# INFO:lda:<410> log likelihood: -786626
# INFO:lda:<420> log likelihood: -786592
# INFO:lda:<430> log likelihood: -786654
# INFO:lda:<440> log likelihood: -786514
# INFO:lda:<450> log likelihood: -786187
# INFO:lda:<460> log likelihood: -785812
# INFO:lda:<470> log likelihood: -785258
# INFO:lda:<480> log likelihood: -785101
# INFO:lda:<490> log likelihood: -785565
# INFO:lda:<500> log likelihood: -785541
# INFO:lda:<510> log likelihood: -785383
# INFO:lda:<520> log likelihood: -785060
# INFO:lda:<530> log likelihood: -785618
# INFO:lda:<540> log likelihood: -785018
# INFO:lda:<550> log likelihood: -785420
# INFO:lda:<560> log likelihood: -785077
# INFO:lda:<570> log likelihood: -785155
# INFO:lda:<580> log likelihood: -784791
# INFO:lda:<590> log likelihood: -784397
# INFO:lda:<600> log likelihood: -784323
# INFO:lda:<610> log likelihood: -784545
# INFO:lda:<620> log likelihood: -783887
# INFO:lda:<630> log likelihood: -783649
# INFO:lda:<640> log likelihood: -783645
# INFO:lda:<650> log likelihood: -783604
# INFO:lda:<660> log likelihood: -784505
# INFO:lda:<670> log likelihood: -783186
# INFO:lda:<680> log likelihood: -783183
# INFO:lda:<690> log likelihood: -783580
# INFO:lda:<700> log likelihood: -783067
# INFO:lda:<710> log likelihood: -783275
# INFO:lda:<720> log likelihood: -782943
# INFO:lda:<730> log likelihood: -782800
# INFO:lda:<740> log likelihood: -783815
# INFO:lda:<750> log likelihood: -783034
# INFO:lda:<760> log likelihood: -783210
# INFO:lda:<770> log likelihood: -783410
# INFO:lda:<780> log likelihood: -783295
# INFO:lda:<790> log likelihood: -782462
# INFO:lda:<800> log likelihood: -782821
# INFO:lda:<810> log likelihood: -782634
# INFO:lda:<820> log likelihood: -782879
# INFO:lda:<830> log likelihood: -782565
# INFO:lda:<840> log likelihood: -782520
# INFO:lda:<850> log likelihood: -783074
# INFO:lda:<860> log likelihood: -782855
# INFO:lda:<870> log likelihood: -782769
# INFO:lda:<880> log likelihood: -782942
# INFO:lda:<890> log likelihood: -783005
# INFO:lda:<900> log likelihood: -782750
# INFO:lda:<910> log likelihood: -782991
# INFO:lda:<920> log likelihood: -783053
# INFO:lda:<930> log likelihood: -782780
# INFO:lda:<940> log likelihood: -782682
# INFO:lda:<950> log likelihood: -782573
# INFO:lda:<960> log likelihood: -782255
# INFO:lda:<970> log likelihood: -782797
# INFO:lda:<980> log likelihood: -783628
# INFO:lda:<990> log likelihood: -782759
# INFO:lda:<999> log likelihood: -782682
# added 10
# 114 videos
# 546 total segments
# INFO:lda:n_documents: 546
# INFO:lda:vocab_size: 33701
# INFO:lda:n_words: 97032
# INFO:lda:n_topics: 60
# INFO:lda:n_iter: 1000
# WARNING:lda:all zero column in document-term matrix found
# INFO:lda:<0> log likelihood: -1371573
# INFO:lda:<10> log likelihood: -924649
# INFO:lda:<20> log likelihood: -888586
# INFO:lda:<30> log likelihood: -872632
# INFO:lda:<40> log likelihood: -861765
# INFO:lda:<50> log likelihood: -853767
# INFO:lda:<60> log likelihood: -848213
# INFO:lda:<70> log likelihood: -843073
# INFO:lda:<80> log likelihood: -839534
# INFO:lda:<90> log likelihood: -836184
# INFO:lda:<100> log likelihood: -833045
# INFO:lda:<110> log likelihood: -830489
# INFO:lda:<120> log likelihood: -829858
# INFO:lda:<130> log likelihood: -827466
# INFO:lda:<140> log likelihood: -825305
# INFO:lda:<150> log likelihood: -825153
# INFO:lda:<160> log likelihood: -823378
# INFO:lda:<170> log likelihood: -822588
# INFO:lda:<180> log likelihood: -821560
# INFO:lda:<190> log likelihood: -820270
# INFO:lda:<200> log likelihood: -819028
# INFO:lda:<210> log likelihood: -818484
# INFO:lda:<220> log likelihood: -817256
# INFO:lda:<230> log likelihood: -817506
# INFO:lda:<240> log likelihood: -816383
# INFO:lda:<250> log likelihood: -815739
# INFO:lda:<260> log likelihood: -815628
# INFO:lda:<270> log likelihood: -814312
# INFO:lda:<280> log likelihood: -814347
# INFO:lda:<290> log likelihood: -813647
# INFO:lda:<300> log likelihood: -814027
# INFO:lda:<310> log likelihood: -813122
# INFO:lda:<320> log likelihood: -812656
# INFO:lda:<330> log likelihood: -812205
# INFO:lda:<340> log likelihood: -812242
# INFO:lda:<350> log likelihood: -811906
# INFO:lda:<360> log likelihood: -811374
# INFO:lda:<370> log likelihood: -812869
# INFO:lda:<380> log likelihood: -811566
# INFO:lda:<390> log likelihood: -811457
# INFO:lda:<400> log likelihood: -810865
# INFO:lda:<410> log likelihood: -810455
# INFO:lda:<420> log likelihood: -810738
# INFO:lda:<430> log likelihood: -809647
# INFO:lda:<440> log likelihood: -810081
# INFO:lda:<450> log likelihood: -810525
# INFO:lda:<460> log likelihood: -810960
# INFO:lda:<470> log likelihood: -810190
# INFO:lda:<480> log likelihood: -810077
# INFO:lda:<490> log likelihood: -809410
# INFO:lda:<500> log likelihood: -809264
# INFO:lda:<510> log likelihood: -808372
# INFO:lda:<520> log likelihood: -808773
# INFO:lda:<530> log likelihood: -808069
# INFO:lda:<540> log likelihood: -808346
# INFO:lda:<550> log likelihood: -808011
# INFO:lda:<560> log likelihood: -808054
# INFO:lda:<570> log likelihood: -807553
# INFO:lda:<580> log likelihood: -806469
# INFO:lda:<590> log likelihood: -806839
# INFO:lda:<600> log likelihood: -806773
# INFO:lda:<610> log likelihood: -806113
# INFO:lda:<620> log likelihood: -806034
# INFO:lda:<630> log likelihood: -806875
# INFO:lda:<640> log likelihood: -806244
# INFO:lda:<650> log likelihood: -806447
# INFO:lda:<660> log likelihood: -806185
# INFO:lda:<670> log likelihood: -805919
# INFO:lda:<680> log likelihood: -805374
# INFO:lda:<690> log likelihood: -805283
# INFO:lda:<700> log likelihood: -805433
# INFO:lda:<710> log likelihood: -806020
# INFO:lda:<720> log likelihood: -804846
# INFO:lda:<730> log likelihood: -805890
# INFO:lda:<740> log likelihood: -805503
# INFO:lda:<750> log likelihood: -805574
# INFO:lda:<760> log likelihood: -805386
# INFO:lda:<770> log likelihood: -805120
# INFO:lda:<780> log likelihood: -805291
# INFO:lda:<790> log likelihood: -804750
# INFO:lda:<800> log likelihood: -804780
# INFO:lda:<810> log likelihood: -804802
# INFO:lda:<820> log likelihood: -804737
# INFO:lda:<830> log likelihood: -804056
# INFO:lda:<840> log likelihood: -804785
# INFO:lda:<850> log likelihood: -804441
# INFO:lda:<860> log likelihood: -804091
# INFO:lda:<870> log likelihood: -803939
# INFO:lda:<880> log likelihood: -803740
# INFO:lda:<890> log likelihood: -804388
# INFO:lda:<900> log likelihood: -804539
# INFO:lda:<910> log likelihood: -804530
# INFO:lda:<920> log likelihood: -805012
# INFO:lda:<930> log likelihood: -804418
# INFO:lda:<940> log likelihood: -804517
# INFO:lda:<950> log likelihood: -804196
# INFO:lda:<960> log likelihood: -803532
# INFO:lda:<970> log likelihood: -803955
# INFO:lda:<980> log likelihood: -804538
# INFO:lda:<990> log likelihood: -803306
# INFO:lda:<999> log likelihood: -803309
# added 7
# 118 videos
# 556 total segments
# INFO:lda:n_documents: 556
# INFO:lda:vocab_size: 33701
# INFO:lda:n_words: 98408
# INFO:lda:n_topics: 61
# INFO:lda:n_iter: 1000
# WARNING:lda:all zero column in document-term matrix found
# INFO:lda:<0> log likelihood: -1393870
# INFO:lda:<10> log likelihood: -936970
# INFO:lda:<20> log likelihood: -901481
# INFO:lda:<30> log likelihood: -886079
# INFO:lda:<40> log likelihood: -877012
# INFO:lda:<50> log likelihood: -870243
# INFO:lda:<60> log likelihood: -864402
# INFO:lda:<70> log likelihood: -859475
# INFO:lda:<80> log likelihood: -855406
# INFO:lda:<90> log likelihood: -851917
# INFO:lda:<100> log likelihood: -849299
# INFO:lda:<110> log likelihood: -846391
# INFO:lda:<120> log likelihood: -845988
# INFO:lda:<130> log likelihood: -843165
# INFO:lda:<140> log likelihood: -841082
# INFO:lda:<150> log likelihood: -839805
# INFO:lda:<160> log likelihood: -837797
# INFO:lda:<170> log likelihood: -837657
# INFO:lda:<180> log likelihood: -836192
# INFO:lda:<190> log likelihood: -834799
# INFO:lda:<200> log likelihood: -833872
# INFO:lda:<210> log likelihood: -833243
# INFO:lda:<220> log likelihood: -832149
# INFO:lda:<230> log likelihood: -831243
# INFO:lda:<240> log likelihood: -830803
# INFO:lda:<250> log likelihood: -830202
# INFO:lda:<260> log likelihood: -829442
# INFO:lda:<270> log likelihood: -828721
# INFO:lda:<280> log likelihood: -828394
# INFO:lda:<290> log likelihood: -827991
# INFO:lda:<300> log likelihood: -828411
# INFO:lda:<310> log likelihood: -826898
# INFO:lda:<320> log likelihood: -827383
# INFO:lda:<330> log likelihood: -826696
# INFO:lda:<340> log likelihood: -826260
# INFO:lda:<350> log likelihood: -826435
# INFO:lda:<360> log likelihood: -826113
# INFO:lda:<370> log likelihood: -825848
# INFO:lda:<380> log likelihood: -825546
# INFO:lda:<390> log likelihood: -824436
# INFO:lda:<400> log likelihood: -824323
# INFO:lda:<410> log likelihood: -824211
# INFO:lda:<420> log likelihood: -824085
# INFO:lda:<430> log likelihood: -823677
# INFO:lda:<440> log likelihood: -823716
# INFO:lda:<450> log likelihood: -824297
# INFO:lda:<460> log likelihood: -823615
# INFO:lda:<470> log likelihood: -823806
# INFO:lda:<480> log likelihood: -824198
# INFO:lda:<490> log likelihood: -823880
# INFO:lda:<500> log likelihood: -823898
# INFO:lda:<510> log likelihood: -824563
# INFO:lda:<520> log likelihood: -823553
# INFO:lda:<530> log likelihood: -822960
# INFO:lda:<540> log likelihood: -823749
# INFO:lda:<550> log likelihood: -823601
# INFO:lda:<560> log likelihood: -823382
# INFO:lda:<570> log likelihood: -823097
# INFO:lda:<580> log likelihood: -823840
# INFO:lda:<590> log likelihood: -822164
# INFO:lda:<600> log likelihood: -822734
# INFO:lda:<610> log likelihood: -823869
# INFO:lda:<620> log likelihood: -823627
# INFO:lda:<630> log likelihood: -822700
# INFO:lda:<640> log likelihood: -821975
# INFO:lda:<650> log likelihood: -823506
# INFO:lda:<660> log likelihood: -822398
# INFO:lda:<670> log likelihood: -822899
# INFO:lda:<680> log likelihood: -822872
# INFO:lda:<690> log likelihood: -822814
# INFO:lda:<700> log likelihood: -822737
# INFO:lda:<710> log likelihood: -821446
# INFO:lda:<720> log likelihood: -821741
# INFO:lda:<730> log likelihood: -821741
# INFO:lda:<740> log likelihood: -821869
# INFO:lda:<750> log likelihood: -821668
# INFO:lda:<760> log likelihood: -821072
# INFO:lda:<770> log likelihood: -821682
# INFO:lda:<780> log likelihood: -821553
# INFO:lda:<790> log likelihood: -822095
# INFO:lda:<800> log likelihood: -821931
# INFO:lda:<810> log likelihood: -821190
# INFO:lda:<820> log likelihood: -822013
# INFO:lda:<830> log likelihood: -821678
# INFO:lda:<840> log likelihood: -821199
# INFO:lda:<850> log likelihood: -821104
# INFO:lda:<860> log likelihood: -822167
# INFO:lda:<870> log likelihood: -821398
# INFO:lda:<880> log likelihood: -820755
# INFO:lda:<890> log likelihood: -820723
# INFO:lda:<900> log likelihood: -821670
# INFO:lda:<910> log likelihood: -820652
# INFO:lda:<920> log likelihood: -820827
# INFO:lda:<930> log likelihood: -821032
# INFO:lda:<940> log likelihood: -821906
# INFO:lda:<950> log likelihood: -820563
# INFO:lda:<960> log likelihood: -821015
# INFO:lda:<970> log likelihood: -820523
# INFO:lda:<980> log likelihood: -820751
# INFO:lda:<990> log likelihood: -821094
# INFO:lda:<999> log likelihood: -820996
# added 4
